# %% [markdown]
# # Imports

# %%
import numpy as np
from scipy.io import loadmat, whosmat, savemat
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import os
import re
import pandas as pd
from tqdm import tqdm
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import pickle
import gc
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, cross_val_score
from sklearn.utils import shuffle
from sklearn.neural_network import MLPClassifier
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Utils

# %%
base_path = ''

# %%
# name of features
features_map = {
  0: 'asm_LDS',
  1: 'asm_movingAve',
  2: 'dasm_LDS',
  3: 'dasm_movingAve',
  4: 'dcau_LDS',
  5: 'dcau_movingAve',
  6: 'de_LDS',
  7: 'de_movingAve',
  8: 'psd_LDS',
  9: 'psd_movingAve',
  10: 'rasm_LDS',
  11: 'rasm_movingAve'
}

# %%
# extract
def ends_with_specific_number(input_string, specific_number):
  pattern = re.compile(rf".*{specific_number}$")
  return bool(pattern.match(input_string))

# %%
'''
Sorts files based on:
  1. subject (Asc)
  2. experiment date (Asc)
'''

def custom_sort(file_name):
  # Extract the number before the underscore and the date
  match = re.match(r'(\d+)_(\d+)', file_name)
  if match:
    number_part = int(match.group(1))
    date_part = int(match.group(2))
    return (number_part, date_part)
  else:
    return (float('inf'), float('inf'))

# %% [markdown]
# # Loading Data

# %%
with open(os.path.join(base_path, 'alldata2.pkl'), 'rb') as file:
  data = pickle.load(file)

# %%
labels = loadmat(os.path.join(base_path, 'label.mat'))['label'][0]
labels_edited = np.empty(675)
for i in range(0,45):
  labels_edited[i*15:(i+1)*15] = labels

# %% [markdown]
# # All Subjects, 5-Fold (Mixed Data), All Features

# %%
results_dict ={
  "SVM": [],
  "K-Nearest Neighbors":[],
  "Logistic Regression": []
}

all_index = [i for i in range(15)]
kf = KFold(n_splits=5, shuffle=False)

data = data.reshape(len(data),-1)

for fold, (train_index, test_index) in enumerate(kf.split(all_index)):
  print(f"\n\nRunning fold {fold}")
  train_indices = np.array([list(range(i*45, (i+1)*45)) for i in train_index ]).flatten()
  test_indices = np.array([list(range(i*45, (i+1)*45)) for i in test_index ]).flatten()

  train_labels = labels_edited[train_indices]
  test_labels = labels_edited[test_indices]

  classifiers = {
    "SVM": SVC(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Logistic Regression": LogisticRegression()
  }

  for name, clf in classifiers.items():
    print(f"{name} started at: {datetime.now().strftime('%H:%M:%S')}")
    clf.fit(data[train_indices], train_labels)
    print(f"{name} trained at: {datetime.now().strftime('%H:%M:%S')}")
    predictions = clf.predict(data[test_indices])
    print(f"{name} predicted at: {datetime.now().strftime('%H:%M:%S')}")
    accuracy = accuracy_score(test_labels, predictions)
    print(f"{name} Accuracy: {accuracy}")
    results_dict[name].append(accuracy)
    del clf
    del predictions
    gc.collect()


df = pd.DataFrame(results_dict)
df.to_csv(os.path.join(base_path, 'final-allsubj-5fold-allfeatures.csv'))
# Out:
# Running fold 0
# SVM started at: 13:47:20
# SVM trained at: 13:57:31
# SVM predicted at: 14:06:03
# SVM Accuracy: 0.32592592592592595
# K-Nearest Neighbors started at: 14:06:05
# K-Nearest Neighbors trained at: 14:06:54
# K-Nearest Neighbors predicted at: 14:07:32
# K-Nearest Neighbors Accuracy: 0.4962962962962963
# Logistic Regression started at: 14:07:32
# Logistic Regression trained at: 14:18:16
# Logistic Regression predicted at: 14:18:27
# Logistic Regression Accuracy: 0.5481481481481482
#
#
# Running fold 1
# SVM started at: 14:18:28
# SVM trained at: 14:27:10
# SVM predicted at: 14:36:17
# SVM Accuracy: 0.3333333333333333
# K-Nearest Neighbors started at: 14:36:18
# K-Nearest Neighbors trained at: 14:37:08
# K-Nearest Neighbors predicted at: 14:37:33
# K-Nearest Neighbors Accuracy: 0.37037037037037035
# Logistic Regression started at: 14:37:34
# Logistic Regression trained at: 14:40:11
# Logistic Regression predicted at: 14:40:32
# Logistic Regression Accuracy: 0.3333333333333333
#
#
# Running fold 2
# SVM started at: 14:40:34
# SVM trained at: 14:49:22
# SVM predicted at: 14:58:30
# SVM Accuracy: 0.3333333333333333
# K-Nearest Neighbors started at: 14:58:31
# K-Nearest Neighbors trained at: 14:59:26
# K-Nearest Neighbors predicted at: 15:00:01
# K-Nearest Neighbors Accuracy: 0.43703703703703706
# Logistic Regression started at: 15:00:02
# Logistic Regression trained at: 15:01:44
# Logistic Regression predicted at: 15:01:59
# Logistic Regression Accuracy: 0.3333333333333333
#
#
# Running fold 3
# SVM started at: 15:02:01
# SVM trained at: 15:10:59
# SVM predicted at: 15:19:56
# SVM Accuracy: 0.3333333333333333
# K-Nearest Neighbors started at: 15:19:57
# K-Nearest Neighbors trained at: 15:20:35
# K-Nearest Neighbors predicted at: 15:21:10
# K-Nearest Neighbors Accuracy: 0.5407407407407407
# Logistic Regression started at: 15:21:10
# Logistic Regression trained at: 15:22:24
# Logistic Regression predicted at: 15:22:33
# Logistic Regression Accuracy: 0.3333333333333333
#
#
# Running fold 4
# SVM started at: 15:22:35
# SVM trained at: 15:31:08
# SVM predicted at: 15:39:33
# SVM Accuracy: 0.3333333333333333
# K-Nearest Neighbors started at: 15:39:33
# K-Nearest Neighbors trained at: 15:40:09
# K-Nearest Neighbors predicted at: 15:40:40
# K-Nearest Neighbors Accuracy: 0.4222222222222222
# Logistic Regression started at: 15:40:40
# Logistic Regression trained at: 15:42:29
# Logistic Regression predicted at: 15:42:47
# Logistic Regression Accuracy: 0.3333333333333333

# %% [markdown]
# # All Subjects, 3 Subjects Aside, All Features

# %%
results_dict ={
  "SVM": [],
  "K-Nearest Neighbors":[],
  "Logistic Regression": []
}

all_index = [i for i in range(15)]
kf = KFold(n_splits=5, shuffle=False)

# data = data.reshape(len(data),-1)

for fold, (train_index, test_index) in enumerate(kf.split(all_index)):
  print(f"\n\nRunning fold {fold}")
  train_indices = np.array([list(range(i*45, (i+1)*45)) for i in train_index ]).flatten()
  test_indices = np.array([list(range(i*45, (i+1)*45)) for i in test_index ]).flatten()

  train_labels = labels_edited[train_indices]
  test_labels = labels_edited[test_indices]

  classifiers = {
    "SVM": SVC(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Logistic Regression": LogisticRegression()
  }

  for name, clf in classifiers.items():
    print(f"{name} started at: {datetime.now().strftime('%H:%M:%S')}")
    clf.fit(data[train_indices], train_labels)
    print(f"{name} trained at: {datetime.now().strftime('%H:%M:%S')}")
    predictions = clf.predict(data[test_indices])
    print(f"{name} predicted at: {datetime.now().strftime('%H:%M:%S')}")
    accuracy = accuracy_score(test_labels, predictions)
    print(f"{name} Accuracy: {accuracy}")
    results_dict[name].append(accuracy)
    del clf
    del predictions
    gc.collect()


df = pd.DataFrame(results_dict)
df.to_csv(os.path.join(base_path, 'final-allsubj-5fold-3subjaside-allfeatures.csv'))
# Out:
# Running fold 0
# SVM started at: 15:54:57
# SVM trained at: 16:01:57
# SVM predicted at: 16:09:52
# SVM Accuracy: 0.32592592592592595
# K-Nearest Neighbors started at: 16:09:53
# K-Nearest Neighbors trained at: 16:10:48
# K-Nearest Neighbors predicted at: 16:11:15
# K-Nearest Neighbors Accuracy: 0.4962962962962963
# Logistic Regression started at: 16:11:16
# Logistic Regression trained at: 16:20:03
# Logistic Regression predicted at: 16:20:12
# Logistic Regression Accuracy: 0.5481481481481482
#
#
# Running fold 1
# SVM started at: 16:20:14
# SVM trained at: 16:27:44
# SVM predicted at: 16:35:32
# SVM Accuracy: 0.3333333333333333
# K-Nearest Neighbors started at: 16:35:33
# K-Nearest Neighbors trained at: 16:36:12
# K-Nearest Neighbors predicted at: 16:36:42
# K-Nearest Neighbors Accuracy: 0.37037037037037035
# Logistic Regression started at: 16:36:43
# Logistic Regression trained at: 16:38:30
# Logistic Regression predicted at: 16:38:39
# Logistic Regression Accuracy: 0.3333333333333333
#
#
# Running fold 2
# SVM started at: 16:38:41
# SVM trained at: 16:45:54
# SVM predicted at: 16:53:56
# SVM Accuracy: 0.3333333333333333
# K-Nearest Neighbors started at: 16:53:57
# K-Nearest Neighbors trained at: 16:55:01
# K-Nearest Neighbors predicted at: 16:55:31
# K-Nearest Neighbors Accuracy: 0.43703703703703706
# Logistic Regression started at: 16:55:32
# Logistic Regression trained at: 16:57:00
# Logistic Regression predicted at: 16:57:09
# Logistic Regression Accuracy: 0.3333333333333333
#
#
# Running fold 3
# SVM started at: 16:57:10
# SVM trained at: 17:04:16
# SVM predicted at: 17:12:29
# SVM Accuracy: 0.3333333333333333
# K-Nearest Neighbors started at: 17:12:30
# K-Nearest Neighbors trained at: 17:13:20
# K-Nearest Neighbors predicted at: 17:13:47
# K-Nearest Neighbors Accuracy: 0.5407407407407407
# Logistic Regression started at: 17:13:49
# Logistic Regression trained at: 17:15:18
# Logistic Regression predicted at: 17:15:35
# Logistic Regression Accuracy: 0.3333333333333333
#
#
# Running fold 4
# SVM started at: 17:15:37
# SVM trained at: 17:22:52
# SVM predicted at: 17:30:34
# SVM Accuracy: 0.3333333333333333
# K-Nearest Neighbors started at: 17:30:35
# K-Nearest Neighbors trained at: 17:31:10
# K-Nearest Neighbors predicted at: 17:31:33
# K-Nearest Neighbors Accuracy: 0.4222222222222222
# Logistic Regression started at: 17:31:34
# Logistic Regression trained at: 17:32:32
# Logistic Regression predicted at: 17:32:50
# Logistic Regression Accuracy: 0.3333333333333333

# %% [markdown]
# # All Subjects, 3 Videos Aside, All Features

# %%
results_dict ={
  "SVM": [],
  "K-Nearest Neighbors":[],
  "Logistic Regression": []
}

data = data.reshape(len(data),-1)

'''
Handling 5-fold on videos:
- Each time we selected 3 videos from each experiment. As we know, each experiment has 15 videos (trials) so
- it will be like we applied 5 fold on videos. In this method we considered that by the original order
- of the trials, each time we expect sad, happy, and neutral video for test.
'''
for k in range (5):
  print(f"\n\nRunning fold {fold}")
  test_index = []
  all_index = [i for i in range (675)]
  train_index=[]
  for e in range(45):
    test_index.extend(list(range(e*15 + 3*k,e*15 + 3*k + 3)))

  train_index = list(set(all_index)-set(test_index))

  train_labels = labels_edited[train_index]
  test_labels = labels_edited[test_index]

  classifiers = {
    "SVM": SVC(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Logistic Regression": LogisticRegression()
  }

  for name, clf in classifiers.items():
    print(f"{name} started at: {datetime.now().strftime('%H:%M:%S')}")
    clf.fit(data[train_index], train_labels)
    print(f"{name} trained at: {datetime.now().strftime('%H:%M:%S')}")
    predictions = clf.predict(data[test_index])
    print(f"{name} predicted at: {datetime.now().strftime('%H:%M:%S')}")
    accuracy = accuracy_score(test_labels, predictions)
    print(f"{name} Accuracy: {accuracy}")
    results_dict[name].append(accuracy)

    del clf
    del predictions
    gc.collect()

df = pd.DataFrame(results_dict)
df.to_csv(os.path.join(base_path, 'final-allsubj-5fold-3vidaside-allfeatures.csv'))
# Out:
# Running fold 4
# SVM started at: 23:33:28
# SVM trained at: 23:41:10
# SVM predicted at: 23:48:57
# SVM Accuracy: 0.3333333333333333
# K-Nearest Neighbors started at: 23:48:58
# K-Nearest Neighbors trained at: 23:49:29
# K-Nearest Neighbors predicted at: 23:49:38
# K-Nearest Neighbors Accuracy: 0.35555555555555557
# Logistic Regression started at: 23:49:39
# Logistic Regression trained at: 23:50:47
# Logistic Regression predicted at: 23:50:49
# Logistic Regression Accuracy: 0.3333333333333333
#
#
# Running fold 4
# SVM started at: 23:50:50
# SVM trained at: 23:58:03
# SVM predicted at: 00:05:42
# SVM Accuracy: 0.3333333333333333
# K-Nearest Neighbors started at: 00:05:42
# K-Nearest Neighbors trained at: 00:05:57
# K-Nearest Neighbors predicted at: 00:06:14
# K-Nearest Neighbors Accuracy: 0.35555555555555557
# Logistic Regression started at: 00:06:15
# Logistic Regression trained at: 00:07:47
# Logistic Regression predicted at: 00:07:55
# Logistic Regression Accuracy: 0.3333333333333333
#
#
# Running fold 4
# SVM started at: 00:07:57
# SVM trained at: 00:14:57
# SVM predicted at: 00:22:33
# SVM Accuracy: 0.3333333333333333
# K-Nearest Neighbors started at: 00:22:34
# K-Nearest Neighbors trained at: 00:22:46
# K-Nearest Neighbors predicted at: 00:23:01
# K-Nearest Neighbors Accuracy: 0.4
# Logistic Regression started at: 00:23:02
# Logistic Regression trained at: 00:24:24
# Logistic Regression predicted at: 00:24:26
# Logistic Regression Accuracy: 0.3333333333333333
#
#
# Running fold 4
# SVM started at: 00:24:27
# SVM trained at: 00:31:54
# SVM predicted at: 00:39:30
# SVM Accuracy: 0.3333333333333333
# K-Nearest Neighbors started at: 00:39:30
# K-Nearest Neighbors trained at: 00:39:41
# K-Nearest Neighbors predicted at: 00:39:55
# K-Nearest Neighbors Accuracy: 0.4074074074074074
# Logistic Regression started at: 00:39:57
# Logistic Regression trained at: 00:41:03
# Logistic Regression predicted at: 00:41:09
# Logistic Regression Accuracy: 0.3333333333333333
#
#
# Running fold 4
# SVM started at: 00:41:10
# SVM trained at: 00:48:40
# SVM predicted at: 00:56:17
# SVM Accuracy: 0.3333333333333333
# K-Nearest Neighbors started at: 00:56:18
# K-Nearest Neighbors trained at: 00:56:32
# K-Nearest Neighbors predicted at: 00:56:48
# K-Nearest Neighbors Accuracy: 0.4666666666666667
# Logistic Regression started at: 00:56:48
# Logistic Regression trained at: 00:57:54
# Logistic Regression predicted at: 00:57:57
# Logistic Regression Accuracy: 0.3333333333333333

# %% [markdown]
# # All Subjects, 3 Subjects Aside, Selected Features

# %%
results_dict ={
  "SVM": [],
  "K-Nearest Neighbors":[],
  "Logistic Regression": []
}

all_index = [i for i in range(15)]
kf = KFold(n_splits=5, shuffle=False)

for fold, (train_index, test_index) in enumerate(kf.split(all_index)):
  print(f"\n\nRunning fold {fold}")
  train_indices = np.array([list(range(i*45, (i+1)*45)) for i in train_index ]).flatten()
  test_indices = np.array([list(range(i*45, (i+1)*45)) for i in test_index ]).flatten()

  train_data = data[train_indices,:,:,:]
  test_data = data[test_indices,:,:,:]
  train_data = train_data[:,[6,7,10,11],:,:].reshape(len(train_indices),-1)
  test_data = test_data[:,[6,7,10,11],:,:].reshape(len(test_indices),-1)
  train_labels = labels_edited[train_indices]
  test_labels = labels_edited[test_indices]

  classifiers = {
    "SVM": SVC(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Logistic Regression": LogisticRegression()
  }

  for name, clf in classifiers.items():
    print(f"{name} started at: {datetime.now().strftime('%H:%M:%S')}")
    clf.fit(train_data, train_labels)
    print(f"{name} trained at: {datetime.now().strftime('%H:%M:%S')}")
    predictions = clf.predict(test_data)
    print(f"{name} predicted at: {datetime.now().strftime('%H:%M:%S')}")
    accuracy = accuracy_score(test_labels, predictions)
    print(f"{name} Accuracy: {accuracy}")
    results_dict[name].append(accuracy)


df = pd.DataFrame(results_dict)
df.to_csv(os.path.join(base_path, 'final-allsubj-5fold-3subjaside-selectedfeatures.csv'))
# Out:
# Running fold 0
# SVM started at: 22:35:22
# SVM trained at: 22:37:01
# SVM predicted at: 22:40:12
# SVM Accuracy: 0.7333333333333333
# K-Nearest Neighbors started at: 22:40:12
# K-Nearest Neighbors trained at: 22:40:12
# K-Nearest Neighbors predicted at: 22:40:15
# K-Nearest Neighbors Accuracy: 0.8148148148148148
# Logistic Regression started at: 22:40:15
# Logistic Regression trained at: 22:41:35
# Logistic Regression predicted at: 22:41:35
# Logistic Regression Accuracy: 0.837037037037037
#
#
# Running fold 1
# SVM started at: 22:42:21
# SVM trained at: 22:44:12
# SVM predicted at: 22:46:45
# SVM Accuracy: 0.7333333333333333
# K-Nearest Neighbors started at: 22:46:45
# K-Nearest Neighbors trained at: 22:46:45
# K-Nearest Neighbors predicted at: 22:46:48
# K-Nearest Neighbors Accuracy: 0.8222222222222222
# Logistic Regression started at: 22:46:48
# Logistic Regression trained at: 22:47:52
# Logistic Regression predicted at: 22:47:52
# Logistic Regression Accuracy: 0.7851851851851852
#
#
# Running fold 2
# SVM started at: 22:48:24
# SVM trained at: 22:50:54
# SVM predicted at: 22:53:33
# SVM Accuracy: 0.7333333333333333
# K-Nearest Neighbors started at: 22:53:33
# K-Nearest Neighbors trained at: 22:53:34
# K-Nearest Neighbors predicted at: 22:53:37
# K-Nearest Neighbors Accuracy: 0.8814814814814815
# Logistic Regression started at: 22:53:37
# Logistic Regression trained at: 22:54:39
# Logistic Regression predicted at: 22:54:39
# Logistic Regression Accuracy: 0.8074074074074075
#
#
# Running fold 3
# SVM started at: 22:55:03
# SVM trained at: 22:57:36
# SVM predicted at: 23:00:33
# SVM Accuracy: 0.7333333333333333
# K-Nearest Neighbors started at: 23:00:33
# K-Nearest Neighbors trained at: 23:00:34
# K-Nearest Neighbors predicted at: 23:00:37
# K-Nearest Neighbors Accuracy: 0.8074074074074075
# Logistic Regression started at: 23:00:37
# Logistic Regression trained at: 23:01:58
# Logistic Regression predicted at: 23:01:58
# Logistic Regression Accuracy: 0.8888888888888888
#
#
# Running fold 4
# SVM started at: 23:03:06
# SVM trained at: 23:04:49
# SVM predicted at: 23:07:50
# SVM Accuracy: 0.7333333333333333
# K-Nearest Neighbors started at: 23:07:50
# K-Nearest Neighbors trained at: 23:07:51
# K-Nearest Neighbors predicted at: 23:07:54
# K-Nearest Neighbors Accuracy: 0.7851851851851852
# Logistic Regression started at: 23:07:54
# Logistic Regression trained at: 23:09:12
# Logistic Regression predicted at: 23:09:12
# Logistic Regression Accuracy: 0.8666666666666667

# %% [markdown]
# # Overfitting Test

# %%
results_dict ={
  "SVM": [],
  "K-Nearest Neighbors":[],
  "Logistic Regression": []
}
steps_dict = [ {
  "SVM": [],
  "K-Nearest Neighbors":[],
  "Logistic Regression": []
} for i in range(3)]

all_index = [i for i in range(15)]
kf = KFold(n_splits=5, shuffle=False)

data = data.reshape(len(data),-1)

for step in range(3):
  print(f"\n\nRunning step {step}")
  for fold, (train_index, test_index) in enumerate(kf.split(all_index)):
    print(f"\n\nRunning fold {fold}")
    train_indices = np.array([list(range(i*45, (i+1)*45)) for i in train_index ]).flatten()
    test_indices = np.array([list(range(i*45, (i+1)*45)) for i in test_index ]).flatten()

    train_labels = labels_edited[train_indices]
    test_labels = labels_edited[test_indices]

    classifiers = {
      "SVM": SVC(),
      "K-Nearest Neighbors": KNeighborsClassifier(),
      "Logistic Regression": LogisticRegression()
    }

    for name, clf in classifiers.items():
      print(f"{name} started at: {datetime.now().strftime('%H:%M:%S')}")
      if os.path.exists(f'./weights/{fold}_{name}.pkl'):
        with open(f'./weights/{fold}_{name}.pkl','rb') as f:
          clf = pickle.load(f)
      else:
        clf.fit(data[train_indices], train_labels)
        with open(f'./weights/{fold}_{name}.pkl','wb') as f:
          pickle.dump(clf,f)
      print(f"{name} trained at: {datetime.now().strftime('%H:%M:%S')}")
      predictions = clf.predict(data[test_indices])
      print(f"{name} predicted at: {datetime.now().strftime('%H:%M:%S')}")
      accuracy = accuracy_score(test_labels, predictions)
      print(f"{name} Accuracy: {accuracy}")
      results_dict[name].append(accuracy)

      train_indices_copy = train_indices.copy()
      test_indices_copy = test_indices.copy()
      test_labels_copy = test_labels.copy()

      all_selecteds = []
      np.random.seed(42)

      
      for s in range(step+1):
        selected = np.random.choice(np.setdiff1d(train_index, all_selecteds))
        start = np.where(train_indices == selected*45)[0][0]
        test_indices_copy[s*45:(s+1)*45] = train_indices[start: start+45]
        test_labels_copy[s*45:(s+1)*45] = train_labels[start: start+45]
        all_selecteds.append(selected)

      predictions = clf.predict(data[test_indices_copy])
      accuracy = accuracy_score(test_labels_copy, predictions)
      steps_dict[step][name].append(accuracy)
      print(f"{step}--{name}--{accuracy}")

      del clf
      del predictions
      gc.collect()


df = pd.DataFrame(results_dict)
df.to_csv(os.path.join(base_path, 'allsubj-5fold-3subjaside-overfit-allfeatures.csv'))

df = pd.DataFrame(steps_dict)
df.to_csv(os.path.join(base_path, 'steps.csv'))
# Out:
# Running step 0
#
#
# Running fold 0
# SVM started at: 18:04:11
# SVM trained at: 18:04:33
# SVM predicted at: 18:09:45
# SVM Accuracy: 0.32592592592592595
# 0--SVM--0.34074074074074073
# K-Nearest Neighbors started at: 18:14:56
# K-Nearest Neighbors trained at: 18:16:38
# K-Nearest Neighbors predicted at: 18:16:43
# K-Nearest Neighbors Accuracy: 0.4962962962962963
# 0--K-Nearest Neighbors--0.5777777777777777
# Logistic Regression started at: 18:16:48
# Logistic Regression trained at: 18:16:49
# Logistic Regression predicted at: 18:16:50
# Logistic Regression Accuracy: 0.562962962962963
# 0--Logistic Regression--0.7111111111111111
#
#
# Running fold 1
# SVM started at: 18:16:50
# SVM trained at: 18:18:32
# SVM predicted at: 18:24:00
# SVM Accuracy: 0.3333333333333333
# 0--SVM--0.3333333333333333
# K-Nearest Neighbors started at: 18:29:11
# K-Nearest Neighbors trained at: 18:30:53
# K-Nearest Neighbors predicted at: 18:30:57
# K-Nearest Neighbors Accuracy: 0.37037037037037035
# 0--K-Nearest Neighbors--0.4444444444444444
# Logistic Regression started at: 18:31:02
# Logistic Regression trained at: 18:31:03
# Logistic Regression predicted at: 18:31:03
# Logistic Regression Accuracy: 0.3333333333333333
# 0--Logistic Regression--0.3333333333333333
#
#
# Running fold 2
# SVM started at: 18:31:04
# SVM trained at: 18:32:52
# SVM predicted at: 18:38:13
# SVM Accuracy: 0.3333333333333333
# 0--SVM--0.3333333333333333
# K-Nearest Neighbors started at: 18:43:07
# K-Nearest Neighbors trained at: 18:44:49
# K-Nearest Neighbors predicted at: 18:44:54
# K-Nearest Neighbors Accuracy: 0.43703703703703706
# 0--K-Nearest Neighbors--0.5037037037037037
# Logistic Regression started at: 18:44:58
# Logistic Regression trained at: 18:45:00
# Logistic Regression predicted at: 18:45:00
# Logistic Regression Accuracy: 0.3333333333333333
# 0--Logistic Regression--0.3333333333333333
#
#
# Running fold 3
# SVM started at: 18:45:01
# SVM trained at: 18:46:43
# SVM predicted at: 18:51:50
# SVM Accuracy: 0.3333333333333333
# 0--SVM--0.3333333333333333
# K-Nearest Neighbors started at: 18:55:49
# K-Nearest Neighbors trained at: 18:57:33
# K-Nearest Neighbors predicted at: 18:57:37
# K-Nearest Neighbors Accuracy: 0.5407407407407407
# 0--K-Nearest Neighbors--0.5777777777777777
# Logistic Regression started at: 18:57:42
# Logistic Regression trained at: 18:57:43
# Logistic Regression predicted at: 18:57:44
# Logistic Regression Accuracy: 0.3333333333333333
# 0--Logistic Regression--0.3333333333333333
#
#
# Running fold 4
# SVM started at: 18:57:44
# SVM trained at: 18:59:27
# SVM predicted at: 19:04:21
# SVM Accuracy: 0.3333333333333333
# 0--SVM--0.3333333333333333
# K-Nearest Neighbors started at: 19:09:03
# K-Nearest Neighbors trained at: 19:10:46
# K-Nearest Neighbors predicted at: 19:10:50
# K-Nearest Neighbors Accuracy: 0.4222222222222222
# 0--K-Nearest Neighbors--0.4666666666666667
# Logistic Regression started at: 19:10:55
# Logistic Regression trained at: 19:10:56
# Logistic Regression predicted at: 19:10:56
# Logistic Regression Accuracy: 0.3333333333333333
# 0--Logistic Regression--0.3333333333333333
#
#
# Running step 1
#
#
# Running fold 0
# SVM started at: 19:10:57
# SVM trained at: 19:12:13
# SVM predicted at: 19:16:53
# SVM Accuracy: 0.32592592592592595
# 1--SVM--0.3333333333333333
# K-Nearest Neighbors started at: 19:21:32
# K-Nearest Neighbors trained at: 19:23:15
# K-Nearest Neighbors predicted at: 19:23:19
# K-Nearest Neighbors Accuracy: 0.4962962962962963
# 1--K-Nearest Neighbors--0.5777777777777777
# Logistic Regression started at: 19:23:24
# Logistic Regression trained at: 19:23:24
# Logistic Regression predicted at: 19:23:25
# Logistic Regression Accuracy: 0.562962962962963
# 1--Logistic Regression--0.7851851851851852
#
#
# Running fold 1
# SVM started at: 19:23:25
# SVM trained at: 19:25:07
# SVM predicted at: 19:29:49
# SVM Accuracy: 0.3333333333333333
# 1--SVM--0.3333333333333333
# K-Nearest Neighbors started at: 19:34:28
# K-Nearest Neighbors trained at: 19:36:11
# K-Nearest Neighbors predicted at: 19:36:15
# K-Nearest Neighbors Accuracy: 0.37037037037037035
# 1--K-Nearest Neighbors--0.5111111111111111
# Logistic Regression started at: 19:36:20
# Logistic Regression trained at: 19:36:21
# Logistic Regression predicted at: 19:36:22
# Logistic Regression Accuracy: 0.3333333333333333
# 1--Logistic Regression--0.3333333333333333
#
#
# Running fold 2
# SVM started at: 19:36:23
# SVM trained at: 19:38:11
# SVM predicted at: 19:43:05
# SVM Accuracy: 0.3333333333333333
# 1--SVM--0.3333333333333333
# K-Nearest Neighbors started at: 19:46:46
# K-Nearest Neighbors trained at: 19:48:29
# K-Nearest Neighbors predicted at: 19:48:34
# K-Nearest Neighbors Accuracy: 0.43703703703703706
# 1--K-Nearest Neighbors--0.5925925925925926
# Logistic Regression started at: 19:48:39
# Logistic Regression trained at: 19:48:40
# Logistic Regression predicted at: 19:48:41
# Logistic Regression Accuracy: 0.3333333333333333
# 1--Logistic Regression--0.3333333333333333
#
#
# Running fold 3
# SVM started at: 19:48:41
# SVM trained at: 19:50:24
# SVM predicted at: 19:55:01
# SVM Accuracy: 0.3333333333333333
# 1--SVM--0.3333333333333333
# K-Nearest Neighbors started at: 19:59:37
# K-Nearest Neighbors trained at: 20:01:22
# K-Nearest Neighbors predicted at: 20:01:26
# K-Nearest Neighbors Accuracy: 0.5407407407407407
# 1--K-Nearest Neighbors--0.6222222222222222
# Logistic Regression started at: 20:01:31
# Logistic Regression trained at: 20:01:33
# Logistic Regression predicted at: 20:01:33
# Logistic Regression Accuracy: 0.3333333333333333
# 1--Logistic Regression--0.3333333333333333
#
#
# Running fold 4
# SVM started at: 20:01:34
# SVM trained at: 20:03:16
# SVM predicted at: 20:07:53
# SVM Accuracy: 0.3333333333333333
# 1--SVM--0.3333333333333333
# K-Nearest Neighbors started at: 20:12:28
# K-Nearest Neighbors trained at: 20:14:10
# K-Nearest Neighbors predicted at: 20:14:14
# K-Nearest Neighbors Accuracy: 0.4222222222222222
# 1--K-Nearest Neighbors--0.5481481481481482
# Logistic Regression started at: 20:14:19
# Logistic Regression trained at: 20:14:20
# Logistic Regression predicted at: 20:14:21
# Logistic Regression Accuracy: 0.3333333333333333
# 1--Logistic Regression--0.3333333333333333
#
#
# Running step 2
#
#
# Running fold 0
# SVM started at: 20:14:21
# SVM trained at: 20:15:59
# SVM predicted at: 20:20:35
# SVM Accuracy: 0.32592592592592595
# 2--SVM--0.3333333333333333
# K-Nearest Neighbors started at: 20:25:14
# K-Nearest Neighbors trained at: 20:26:56
# K-Nearest Neighbors predicted at: 20:27:00
# K-Nearest Neighbors Accuracy: 0.4962962962962963
# 2--K-Nearest Neighbors--0.5851851851851851
# Logistic Regression started at: 20:27:05
# Logistic Regression trained at: 20:27:06
# Logistic Regression predicted at: 20:27:06
# Logistic Regression Accuracy: 0.562962962962963
# 2--Logistic Regression--0.8592592592592593
#
#
# Running fold 1
# SVM started at: 20:27:07
# SVM trained at: 20:28:48
# SVM predicted at: 20:33:28
# SVM Accuracy: 0.3333333333333333
# 2--SVM--0.3333333333333333
# K-Nearest Neighbors started at: 20:38:06
# K-Nearest Neighbors trained at: 20:39:48
# K-Nearest Neighbors predicted at: 20:39:52
# K-Nearest Neighbors Accuracy: 0.37037037037037035
# 2--K-Nearest Neighbors--0.5777777777777777
# Logistic Regression started at: 20:39:57
# Logistic Regression trained at: 20:39:58
# Logistic Regression predicted at: 20:39:58
# Logistic Regression Accuracy: 0.3333333333333333
# 2--Logistic Regression--0.3333333333333333
#
#
# Running fold 2
# SVM started at: 20:39:59
# SVM trained at: 20:41:47
# SVM predicted at: 20:46:25
# SVM Accuracy: 0.3333333333333333
# 2--SVM--0.3333333333333333
# K-Nearest Neighbors started at: 20:51:01
# K-Nearest Neighbors trained at: 20:52:43
# K-Nearest Neighbors predicted at: 20:52:47
# K-Nearest Neighbors Accuracy: 0.43703703703703706
# 2--K-Nearest Neighbors--0.5925925925925926
# Logistic Regression started at: 20:52:52
# Logistic Regression trained at: 20:52:53
# Logistic Regression predicted at: 20:52:54
# Logistic Regression Accuracy: 0.3333333333333333
# 2--Logistic Regression--0.3333333333333333
#
#
# Running fold 3
# SVM started at: 20:52:54
# SVM trained at: 20:54:37
# SVM predicted at: 20:59:13
# SVM Accuracy: 0.3333333333333333
# 2--SVM--0.3333333333333333
# K-Nearest Neighbors started at: 21:03:49
# K-Nearest Neighbors trained at: 21:05:34
# K-Nearest Neighbors predicted at: 21:05:38
# K-Nearest Neighbors Accuracy: 0.5407407407407407
# 2--K-Nearest Neighbors--0.6
# Logistic Regression started at: 21:05:43
# Logistic Regression trained at: 21:05:44
# Logistic Regression predicted at: 21:05:45
# Logistic Regression Accuracy: 0.3333333333333333
# 2--Logistic Regression--0.3333333333333333
#
#
# Running fold 4
# SVM started at: 21:05:45
# SVM trained at: 21:07:27
# SVM predicted at: 21:12:04
# SVM Accuracy: 0.3333333333333333
# 2--SVM--0.3333333333333333
# K-Nearest Neighbors started at: 21:16:39
# K-Nearest Neighbors trained at: 21:18:21
# K-Nearest Neighbors predicted at: 21:18:25
# K-Nearest Neighbors Accuracy: 0.4222222222222222
# 2--K-Nearest Neighbors--0.6370370370370371
# Logistic Regression started at: 21:18:30
# Logistic Regression trained at: 21:18:32
# Logistic Regression predicted at: 21:18:32
# Logistic Regression Accuracy: 0.3333333333333333
# 2--Logistic Regression--0.3333333333333333
